# %% [markdown]
# # 🔥First Python Finance Code!🔥

# %% [markdown]
# ## Fetching Real Stock Data from Yahoo Finance
# - Tesla
# - AAPL
# - GOOGL
# - RELIANCE.NS

# %%
import yfinance as yf
import pandas as pd

# Download data for the above stocks
stock_tsla = yf.download("TSLA", start="2023-01-01", end="2024-01-01") # Tesla
stock_apple = yf.download("AAPL", start="2023-01-01", end="2024-01-01") # Apple
stock_google = yf.download("GOOGL", start="2023-01-01", end="2024-01-01") # Google
stock_reli = yf.download("RELIANCE.NS", start="2023-01-01", end="2024-01-01") # Reliance

# Show the first few rows for each stock
print("Tesla stock data:")
print(stock_tsla.head())
print("\nApple stock data:")
print(stock_apple.head())
print("\nGoogle stock data:")
print(stock_google.head())
print("\nReliance stock data:")
print(stock_reli.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Tesla stock data:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2023-01-03  108.099998  118.800003  104.639999  118.470001  231402800
# 2023-01-04  113.639999  114.589996  107.519997  109.110001  180389000
# 2023-01-05  110.339996  111.750000  107.160004  110.510002  157986300
# 2023-01-06  113.059998  114.389999  101.809998  103.000000  220911100
# 2023-01-09  119.769997  123.519997  117.110001  118.959999  190284000
#
# Apple stock data:
# Price            Close        High         Low        Open     Volume
# ...

# %% [markdown]
# ### Working with one stock at a time
# 1. Tesla

# %%
stock = stock_tsla

# Show basic info
print("\nStock info:")
print(stock.info())

# Show statistical summary
print("\nStatistical summary:")
print(stock.describe())

# Select only 'Close' price column
close_prices = stock["Close"]
print("\nClose prices:")
print(close_prices.head())

# Calculate daily returns
daily_returns = close_prices.pct_change()
print("\nDaily returns:")
print(daily_returns.head())
# Out:
# Stock info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 250 entries, 2023-01-03 to 2023-12-29
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   250 non-null    float64
#  1   (High, TSLA)    250 non-null    float64
#  2   (Low, TSLA)     250 non-null    float64
#  3   (Open, TSLA)    250 non-null    float64
#  4   (Volume, TSLA)  250 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.7 KB
# None
#
# Statistical summary:
# Price        Close        High         Low        Open        Volume
# Ticker        TSLA        TSLA        TSLA        TSLA          TSLA
# count   250.000000  250.000000  250.000000  250.000000  2.500000e+02
# mean    217.475240  221.631680  212.674320  217.075040  1.373222e+08
# std      41.916800   42.458512   41.831715   42.282592  3.577310e+07
# min     108.099998  111.750000  101.809998  103.000000  6.512520e+07
# ...

# %% [markdown]
# # It was ok!!!!

# %% [markdown]
# ## Visualizing Stock Prices

# %%
import matplotlib.pyplot as plt

# Plot stock price trend
stock["Close"].plot(figsize=(10,5), title="Stock Closing Price")
plt.show()

# %%
import seaborn as sns

# Create a figure
plt.figure(figsize=(10,5))

# Plot closing prices with Seaborn
sns.lineplot(data=stock["Close"], label="Stock Price", color="blue")

plt.title("Stock Price Trend")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4 plt.figure(figsize=(10,5))
#       6 # Plot closing prices with Seaborn
# ----> 7 sns.lineplot(data=stock["Close"], label="Stock Price", color="blue")
#       9 plt.title("Stock Price Trend")
#      10 plt.xlabel("Date")
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# ...
